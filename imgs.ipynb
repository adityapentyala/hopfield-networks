# %%
from src.hopfield_network import read_pbm
import matplotlib.pyplot as plt
import os

# %%
for fpath in os.listdir("data"):
    if fpath.split(".")[-1]=="pbm":
        plt.imshow(read_pbm("data/"+fpath))
        plt.title(fpath.split(".")[0])
        plt.show()
